# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore")

# %%
#reading data from csv file
data = pd.read_csv("dataset.csv", low_memory=False)

# %%
#understanding the data

# %%
data
# Out:
#        first_name middle_initial   last_name suffix system  agency  \
# 0            JOHN              C      POLIKS    NaN     RG  290201
# 1            CARL            NaN  CHAMBERLIN    NaN     RG  290201
# 2       JOSEPHINE              K      OBONYO    NaN     RG  290201
# 3            LORI              J    MCFARLIN    NaN     RG  290201
# 4          ELWOOD              D        HALL     JR     RG  290201
# ...           ...            ...         ...    ...    ...     ...
# 174992      EDDIE              L     JOHNSON    NaN     CT  500216
# 174993      JAMES            NaN    JENNINGS    NaN     CT  500216
# 174994       EDNA              M        BLUE    NaN     CT  500220
# 174995     CAROLE            NaN   ABRUZZESE    NaN     CT  500220
# 174996      FENDA              P   WHITELOCK    NaN     CT  500222
#
#                         organization subtitle  class_code  annual_salary  \
# 0       DEPARTMENT OF TRANSPORTATION   290201        8096       71000.00
# ...

# %%
data.head(10)
# Out:
#   first_name middle_initial    last_name suffix system  agency  \
# 0       JOHN              C       POLIKS    NaN     RG  290201
# 1       CARL            NaN   CHAMBERLIN    NaN     RG  290201
# 2  JOSEPHINE              K       OBONYO    NaN     RG  290201
# 3       LORI              J     MCFARLIN    NaN     RG  290201
# 4     ELWOOD              D         HALL     JR     RG  290201
# 5  KATHERINE              J         READ    NaN     RG  290201
# 6    JEFFREY              L       ROBERT    NaN     RG  290201
# 7     THOMAS              F       BROCHU    NaN     RG  290201
# 8   LORRAINE              D  MCCALLISTER    NaN     RG  290201
# 9       MARK              D       GILLIS    NaN     RG  290201
#
#                    organization subtitle  class_code  annual_salary pay_rate  \
# 0  DEPARTMENT OF TRANSPORTATION   290201        8096        71000.0        A
# 1  DEPARTMENT OF TRANSPORTATION   290201         515        96000.0        A
# ...

# %%
data.tail(10)
# Out:
#        first_name middle_initial  last_name suffix system  agency  \
# 174987      LINDA              A     DANNER    NaN     CT  500206
# 174988        KAY              K     TURNER    NaN     CT  500213
# 174989      MIHIR            NaN   MAJUMDAR    NaN     CT  500213
# 174990     REANNA              C     BEATTY    NaN     CT  500215
# 174991     MARION              W    JACKSON    NaN     CT  500215
# 174992      EDDIE              L    JOHNSON    NaN     CT  500216
# 174993      JAMES            NaN   JENNINGS    NaN     CT  500216
# 174994       EDNA              M       BLUE    NaN     CT  500220
# 174995     CAROLE            NaN  ABRUZZESE    NaN     CT  500220
# 174996      FENDA              P  WHITELOCK    NaN     CT  500222
#
#              organization subtitle  class_code  annual_salary pay_rate  \
# 174987  REGISTER OF WILLS      NaN        8990          18.29        H
# 174988  REGISTER OF WILLS      NaN        9702          45.23        H
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174997 entries, 0 to 174996
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   first_name          174993 non-null  object
#  1   middle_initial      135796 non-null  object
#  2   last_name           174989 non-null  object
#  3   suffix              3681 non-null    object
#  4   system              174997 non-null  object
#  5   agency              174997 non-null  int64
#  6   organization        174997 non-null  object
#  7   subtitle            99305 non-null   object
#  8   class_code          174997 non-null  int64
#  9   annual_salary       174997 non-null  float64
#  10  pay_rate            174997 non-null  object
#  11  regular_earnings    174997 non-null  int64
#  12  overtime_earnings   174997 non-null  int64
#  13  other_earnings      174997 non-null  int64
#  14  ytd_gross_earnings  174997 non-null  int64
# ...

# %%
#Calculating the statistical data in %,mean,std
data.describe()
# Out:
#               agency     class_code  annual_salary  regular_earnings  \
# count  174997.000000  174997.000000  174997.000000     174997.000000
# mean   336681.773539    4220.277468   32332.903477      32136.368052
# std     45957.199216    3321.050493   44917.711179      42001.742161
# min    210101.000000       1.000000       0.000000      -4000.000000
# 25%    321209.000000    1111.000000       0.000000          0.000000
# 50%    360222.000000    2941.000000     153.340000      16000.000000
# 75%    360227.000000    8200.000000   55000.000000      52000.000000
# max    500224.000000    9991.000000  961000.000000     965000.000000
#
#        overtime_earnings  other_earnings  ytd_gross_earnings
# count      174997.000000    1.749970e+05        1.749970e+05
# mean         1656.483825    2.446075e+03        3.623881e+04
# std          7295.668501    1.001522e+04        4.516547e+04
# min         -2000.000000   -1.820000e+04        0.000000e+00
# ...

# %%
#to know the size of dataset
data.shape
# Out:
# (174997, 16)

# %%
#displays the column names
data.columns
# Out:
# Index(['first_name', 'middle_initial', 'last_name', 'suffix', 'system',
#        'agency', 'organization', 'subtitle', 'class_code', 'annual_salary',
#        'pay_rate', 'regular_earnings', 'overtime_earnings', 'other_earnings',
#        'ytd_gross_earnings', 'term_date'],
#       dtype='object')

# %%
data['pay_rate'].unique()
# Out:
# array(['A', 'H', 'D'], dtype=object)

# %%
data['pay_rate'].unique()#data visualization using histogram
plt.rcParams["figure.figsize"]=(10,10)               #
data.hist()
plt.show()

# %%
#visualisation using scatterplot
pd.plotting.scatter_matrix(data,figsize=(15,15))
plt.show()

# %% [markdown]
# ### Data Description

# %% [markdown]
# first_name - firstname of the person.
# middle_initial  - middle name of the person.
# last_name - last name of the person.
# suffix - suffix
# system - system
# agency -agency
# organization - Departments.
# subtitle - subtitle
# class_code - class code.
# annual_salary - annual salary of a a person
# pay_rate - Grades for the payrate.
# regular_earnings - Actual salary of a person.
# overtime_earnings - Salary for overtime working hours.
# other_earnings - other earnings offered by the company like bonus etc.
# ytd_gross_earnings - gross earnings of a person
# term_date - term date of person in series

# %%
#unique values in columns
data.nunique()
# Out:
# first_name            28475
# middle_initial           28
# last_name             53437
# suffix                   10
# system                    3
# agency                  250
# organization             75
# subtitle                 55
# class_code             2853
# annual_salary          2659
# pay_rate                  3
# regular_earnings        470
# overtime_earnings       350
# other_earnings          704
# ytd_gross_earnings      480
# term_date              2700
# dtype: int64

# %%
#uniques values for each column  
data['first_name'].unique()
# Out:
# array(['JOHN', 'CARL', 'JOSEPHINE', ..., 'IKEA', 'QUANSHAY', 'FENDA'],
#       dtype=object)

# %%
#cleaning the data

# %%
#total values in the dataset
data.isna().sum().any()
# Out:
# True

# %%
#null values in number
data.isna().sum().sum()
# Out:
# 418584

# %%
#to find the null values
data.isnull().sum()
# Out:
# first_name                 4
# middle_initial         39201
# last_name                  8
# suffix                171316
# system                     0
# agency                     0
# organization               0
# subtitle               75692
# class_code                 0
# annual_salary              0
# pay_rate                   0
# regular_earnings           0
# overtime_earnings          0
# other_earnings             0
# ytd_gross_earnings         0
# term_date             132363
# dtype: int64

# %%
#visualising in heatmap
sns.heatmap(data.isna())
# Out:
# <AxesSubplot:>

# %%
#Frequency of missing values
freq=data.isna().sum()/(len(data))*100
freq
# Out:
# first_name             0.002286
# middle_initial        22.400955
# last_name              0.004572
# suffix                97.896535
# system                 0.000000
# agency                 0.000000
# organization           0.000000
# subtitle              43.253313
# class_code             0.000000
# annual_salary          0.000000
# pay_rate               0.000000
# regular_earnings       0.000000
# overtime_earnings      0.000000
# other_earnings         0.000000
# ytd_gross_earnings     0.000000
# term_date             75.637297
# dtype: float64

# %%
#dropping the columns
data.drop(columns=['middle_initial','subtitle','suffix'])
# Out:
#        first_name   last_name system  agency                  organization  \
# 0            JOHN      POLIKS     RG  290201  DEPARTMENT OF TRANSPORTATION
# 1            CARL  CHAMBERLIN     RG  290201  DEPARTMENT OF TRANSPORTATION
# 2       JOSEPHINE      OBONYO     RG  290201  DEPARTMENT OF TRANSPORTATION
# 3            LORI    MCFARLIN     RG  290201  DEPARTMENT OF TRANSPORTATION
# 4          ELWOOD        HALL     RG  290201  DEPARTMENT OF TRANSPORTATION
# ...           ...         ...    ...     ...                           ...
# 174992      EDDIE     JOHNSON     CT  500216             REGISTER OF WILLS
# 174993      JAMES    JENNINGS     CT  500216             REGISTER OF WILLS
# 174994       EDNA        BLUE     CT  500220             REGISTER OF WILLS
# 174995     CAROLE   ABRUZZESE     CT  500220             REGISTER OF WILLS
# 174996      FENDA   WHITELOCK     CT  500222             REGISTER OF WILLS
#
#         class_code  annual_salary pay_rate  regular_earnings  \
# ...

# %%
#dropping termdate
data.drop('term_date',axis=1)
# Out:
#        first_name middle_initial   last_name suffix system  agency  \
# 0            JOHN              C      POLIKS    NaN     RG  290201
# 1            CARL            NaN  CHAMBERLIN    NaN     RG  290201
# 2       JOSEPHINE              K      OBONYO    NaN     RG  290201
# 3            LORI              J    MCFARLIN    NaN     RG  290201
# 4          ELWOOD              D        HALL     JR     RG  290201
# ...           ...            ...         ...    ...    ...     ...
# 174992      EDDIE              L     JOHNSON    NaN     CT  500216
# 174993      JAMES            NaN    JENNINGS    NaN     CT  500216
# 174994       EDNA              M        BLUE    NaN     CT  500220
# 174995     CAROLE            NaN   ABRUZZESE    NaN     CT  500220
# 174996      FENDA              P   WHITELOCK    NaN     CT  500222
#
#                         organization subtitle  class_code  annual_salary  \
# 0       DEPARTMENT OF TRANSPORTATION   290201        8096       71000.00
# ...

# %%
#to display datatypes
data.dtypes
# Out:
# first_name             object
# middle_initial         object
# last_name              object
# suffix                 object
# system                 object
# agency                  int64
# organization           object
# subtitle               object
# class_code              int64
# annual_salary         float64
# pay_rate               object
# regular_earnings        int64
# overtime_earnings       int64
# other_earnings          int64
# ytd_gross_earnings      int64
# term_date              object
# dtype: object

# %%
#dictionary to change datatypes
convert_dict = {'regular_earnings':float,'overtime_earnings':float,'other_earnings':float,'ytd_gross_earnings':float}

# %%
#to convert datatype
data = data.astype(convert_dict)

# %%
#display the datatypes
data.dtypes
# Out:
# first_name             object
# middle_initial         object
# last_name              object
# suffix                 object
# system                 object
# agency                  int64
# organization           object
# subtitle               object
# class_code              int64
# annual_salary         float64
# pay_rate               object
# regular_earnings      float64
# overtime_earnings     float64
# other_earnings        float64
# ytd_gross_earnings    float64
# term_date              object
# dtype: object

# %%
#computing the columns excluding null values
corelation=data.corr()  
corelation
# Out:
#                       agency  class_code  annual_salary  regular_earnings  \
# agency              1.000000   -0.300730      -0.051477         -0.055257
# class_code         -0.300730    1.000000      -0.063261         -0.033351
# annual_salary      -0.051477   -0.063261       1.000000          0.929772
# regular_earnings   -0.055257   -0.033351       0.929772          1.000000
# overtime_earnings   0.045644    0.017037       0.109816          0.109167
# other_earnings      0.080106   -0.131648       0.072529          0.062789
# ytd_gross_earnings -0.026366   -0.057367       0.898537          0.961555
#
#                     overtime_earnings  other_earnings  ytd_gross_earnings
# agency                       0.045644        0.080106           -0.026366
# class_code                   0.017037       -0.131648           -0.057367
# annual_salary                0.109816        0.072529            0.898537
# regular_earnings             0.109167        0.062789            0.961555
# ...

# %%
#corelation heat map
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
#pairing the relations in dataset
sns.pairplot(data)

# %%
#to count the number of organizations
data['organization'].value_counts()
# Out:
# UNIVERSITY OF MARYLAND            65715
# STATE UNIVERSITIES & COLLEGES     25714
# MARYLAND DEPARTMENT OF HEALTH     13179
# DEPARTMENT OF TRANSPORTATION       9240
# DEPT OF PUB SAFETY & COR SERVS     7125
#                                   ...
# BD-MD TCHR&ST EMP SUPP RET PLN       13
# GOVERNOR'S OFFICE FOR CHILDREN       12
# BOARD OF PUBLIC WORKS                12
# MARYLAND TAX COURT                    9
# CANAL PLACE PRESERV & DEV AUTH        4
# Name: organization, Length: 75, dtype: int64

# %%
#grouping the organization to display the first value
d=data.groupby('organization')
d.first()
# Out:
#                                first_name middle_initial   last_name suffix  \
# organization
# BALTO CITY COMMUNITY COLLEGE       DANIEL              A     STAPLES     JR
# BD-MD TCHR&ST EMP SUPP RET PLN       LARA              L  HJORTSBERG     JR
# BOARD OF PUBLIC WORKS             WILLIAM              M    MORGANTE   None
# CANAL PLACE PRESERV & DEV AUTH    ROXANNE              L      SNYDER   None
# COMPTROLLER OF MARYLAND             PETER              F    FRANCHOT    III
# ...                                   ...            ...         ...    ...
# STATE TREASURER                   KRISTEN              J    ROBINSON   None
# STATE UNIVERSITIES & COLLEGES       SABAH              F       UDDIN     JR
# SUBSEQUENT INJURY FUND           MYCKEETA              T    SAUNDERS     JR
# UNIVERSITY OF MARYLAND             ROBERT              T        CHOW    III
# WORKERS' COMPENSATION COM           YULIA              A       VERMA     JR
#
# ...

# %%
#to display the system in the column grouping with first value
d=data.groupby(['organization','system'])
d.first()
# Out:
#                                       first_name middle_initial   last_name  \
# organization                   system
# BALTO CITY COMMUNITY COLLEGE   CT          AARON              R    LUDENSKY
#                                RG         DANIEL              A     STAPLES
# BD-MD TCHR&ST EMP SUPP RET PLN RG           LARA              L  HJORTSBERG
# BOARD OF PUBLIC WORKS          CT      ALEXANDER              M     DONAHUE
#                                RG        WILLIAM              M    MORGANTE
# ...                                          ...            ...         ...
# STATE UNIVERSITIES & COLLEGES  RG          SABAH              F       UDDIN
# SUBSEQUENT INJURY FUND         RG       MYCKEETA              T    SAUNDERS
# UNIVERSITY OF MARYLAND         UM         ROBERT              T        CHOW
# WORKERS' COMPENSATION COM      CT          RENEE              E    KENDRICK
#                                RG          YULIA              A       VERMA
#
# ...

# %%
#visulation of organization using histogram
plt.figure(figsize=(16,12))
plt.hist(data['organization'])
plt.xticks(rotation=90)
plt.xlabel("Organization",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.title("Organization",fontsize=14)
plt.show()

# %%
#visualisingthe relationship b/w numerical variables 
plt.figure(figsize=(16,12))
plt.plot(data['organization'],data['annual_salary'])
plt.xticks(rotation=90)
plt.show()

# %%
#visualising the regular earning using histogram
plt.figure(figsize=(14,10))
plt.hist(data['regular_earnings'])
plt.xticks(rotation=90)
plt.xlabel("Regular Earnings",fontsize=10)
plt.ylabel("Frequency",fontsize=10)
plt.title("Earnings",fontsize=14)
plt.show()

# %%
#visualising the relation between organization and regular eranings
plt.figure(figsize=(16,12))
plt.plot(data['organization'],data['regular_earnings'])
plt.xticks(rotation=90)
plt.show()

# %%
#visualisation of regular ernings using distribution plot
plt.figure(figsize=(6,6))
sns.distplot(data['regular_earnings'])
plt.show()
# Out:
# /Users/harshithayentrapragada/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Converting categorical variables into Numerics
from sklearn.preprocessing import LabelEncoder
categorical_features=['organization','pay_rate']
encoder=LabelEncoder()
data[categorical_features]=data[categorical_features].apply(encoder.fit_transform)

# %%
data.head(5)
# Out:
#   first_name middle_initial   last_name suffix system  agency  organization  \
# 0       JOHN              C      POLIKS    NaN     RG  290201             9
# 1       CARL            NaN  CHAMBERLIN    NaN     RG  290201             9
# 2  JOSEPHINE              K      OBONYO    NaN     RG  290201             9
# 3       LORI              J    MCFARLIN    NaN     RG  290201             9
# 4     ELWOOD              D        HALL     JR     RG  290201             9
#
#   subtitle  class_code  annual_salary  pay_rate  regular_earnings  \
# 0   290201        8096        71000.0         0           70000.0
# 1   290201         515        96000.0         0           93000.0
# 2   290201        4849        73000.0         0           69000.0
# 3   290201        7480        73000.0         0           70000.0
# 4   290201        7896        52000.0         0           51000.0
#
#    overtime_earnings  other_earnings  ytd_gross_earnings term_date
# ...

# %%
#visualising pay rate data using histogram plot
plt.figure(figsize=(8,8))
plt.hist(data['pay_rate'])
plt.xticks(rotation=90)
plt.xlabel("Pay Rate",fontsize=10)
plt.ylabel("Frequency",fontsize=10)
plt.title("Pays",fontsize=14)
plt.show()

# %%
#visualising organization using histogra,m plot
plt.figure(figsize=(8,8))
sns.histplot(data['organization'])
plt.show()
